# %%
import pandas as pd
import numpy as np
import random
import json
import csv
import itertools
import torch
from transformers import BertTokenizer, BertForSequenceClassification
# Out:
# c:\Users\ensar\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data_fname = './datasets/valid_new.csv'
test_df = pd.read_csv(data_fname)

# %%
test_df
# Out:
#     Unnamed: 0                                          sentences  \
# 0            0  the pharmacokinetics of tolbutamide in all vin...
# 1            1  the pharmacokinetics of tolbutamide in all vin...
# 2            2  the plasma concentrations of the six probes we...
# 3            3  the plasma concentrations of the six probes we...
# 4            4  the plasma concentrations of the six probes we...
# 5            5  the plasma concentrations of the six probes we...
# 6            6  the plasma concentrations of the six probes we...
# 7            7  the plasma concentrations of the six probes we...
# 8            8  the reason of different therapeutic effects of...
# 9            9  the reason of different therapeutic effects of...
# 10          10  the reason of different therapeutic effects of...
# 11          11  the reason of different therapeutic effects of...
# 12          12  the st john's wort component, hyperforin, cont...
# 13          13  the st john's wort component, hyperforin, cont...
# 14          14  the t. bellerica/cisplatin or doxorubicin also...
# 15          15  the t. bellerica/cisplatin or doxorubicin also...
# 16          16  the trend of the graphs strongly suggests that...
# 17          17  there was no significant change in clotting ti...
# 18          18  there was no significant change in clotting ti...
# 19          19  there was significant (p < 0.05) potentiation ...
# 20          20  therefore, a. officinarum might have a gastroi...
# 21          21  these interactions were classified depending o...
# 22          22  this case report describes the first known cas...
# 23          23  this case report describes the first known cas...
# 24          24  this in vitro study demonstrated that various ...
# 25          25  this in vitro study demonstrated that various ...
# 26          26  this in vitro study demonstrated that various ...
# 27          27  this paper is a review of possible adverse int...
# 28          28  this study was designed to explore the impact ...
# 29          29  this study was designed to explore the impact ...
# 30          30  tissue distribution results demonstrated that ...
# 31          31  to evaluate whether ape or andrographolide aff...
# 32          32  treatment of radix bupleuri decreased t1/2 and...
# 33          33  treatment of radix bupleuri decreased t1/2 and...
# 34          34  tunel assay was done followed by expression an...
# 35          35  warfarin was the most common drug (18 cases) a...
# 36          36  we set out to study the interactions of g. bil...
# 37          37  we set out to study the interactions of g. bil...
# 38          38  we studied potential interference of ginseng i...
# 39          39  we studied potential interference of ginseng i...
# 40          40  with the discontinuation of the licorice-conta...
#
#                 entity_1_mention entity_1_label              entity_2_mention  \
# 0                    tolbutamide       CHEMICAL  vinegar-baked radix bupleuri
# 1                 radix bupleuri           HERB                   tolbutamide
# 2                      midazolam       CHEMICAL                radix bupleuri
# 3                      midazolam       CHEMICAL  vinegar-baked radix bupleuri
# 4               dextromethorphan       CHEMICAL                radix bupleuri
# 5               dextromethorphan       CHEMICAL  vinegar-baked radix bupleuri
# 6                  chlorzoxazone       CHEMICAL                radix bupleuri
# 7                  chlorzoxazone       CHEMICAL  vinegar-baked radix bupleuri
# 8                 radix bupleuri           HERB                        cyp2c9
# 9   vinegar-baked radix bupleuri           HERB                       cyp2c19
# 10                radix bupleuri           HERB                        cyp2c9
# 11  vinegar-baked radix bupleuri           HERB                       cyp2c19
# 12                st john's wort           HERB                        cyp3a4
# 13                    hyperforin  HERB_COMPOUND                        cyp3a4
# 14                  t. bellerica           HERB                     cisplatin
# 15                  t. bellerica           HERB                   doxorubicin
# 16                st john's wort           HERB                  cyclosporine
# 17                     g. biloba           HERB                    cilostazol
# 18                     g. biloba           HERB                   clopidogrel
# 19                    cilostazol       CHEMICAL                     g. biloba
# 20                a. officinarum           HERB                  indomethacin
# 21                         herbs           HERB                      warfarin
# 22                    paclitaxel       CHEMICAL                      turmeric
# 23                    paclitaxel       CHEMICAL                     chlorella
# 24                          vbrb           HERB             cyp2c9 substrates
# 25                          vbrb           HERB                       cyp1a2-
# 26                          vbrb           HERB      cyp3a4-metabolized drugs
# 27                          khat           HERB            conventional drugs
# 28                      cinnamon           HERB                     metformin
# 29                      cinnamon           HERB                         cyp2d
# 30                a. officinarum           HERB                  indomethacin
# 31               andrographolide  HERB_COMPOUND                   tolbutamide
# 32                radix bupleuri           HERB                    omeprazole
# 33  vinegar-baked radix bupleuri           HERB                    omeprazole
# 34                           dox       CHEMICAL                      curcumin
# 35                      warfarin       CHEMICAL                st john's wort
# 36                     g. biloba           HERB                    cilostazol
# 37                     g. biloba           HERB                   clopidogrel
# 38                       ginseng           HERB                       digoxin
# 39              siberian ginseng           HERB                       digoxin
# 40                      licorice           HERB                spironolactone
#
#    entity_2_label         type
# 0            HERB     NEGATIVE
# 1        CHEMICAL     POSITIVE
# 2            HERB     POSITIVE
# 3            HERB     POSITIVE
# 4            HERB     POSITIVE
# 5            HERB     POSITIVE
# 6            HERB     POSITIVE
# 7            HERB     POSITIVE
# 8        CHEMICAL     POSITIVE
# 9        CHEMICAL     POSITIVE
# 10       CHEMICAL     POSITIVE
# 11       CHEMICAL     POSITIVE
# 12       CHEMICAL     POSITIVE
# 13       CHEMICAL     POSITIVE
# 14       CHEMICAL     POSITIVE
# 15       CHEMICAL     POSITIVE
# 16       CHEMICAL     POSITIVE
# 17       CHEMICAL     NEGATIVE
# 18       CHEMICAL     NEGATIVE
# 19           HERB     POSITIVE
# 20       CHEMICAL     POSITIVE
# 21       CHEMICAL     POSITIVE
# 22           HERB     POSITIVE
# 23           HERB     POSITIVE
# 24       CHEMICAL     POSITIVE
# 25       CHEMICAL     POSITIVE
# 26       CHEMICAL     POSITIVE
# 27       CHEMICAL  SPECULATIVE
# 28       CHEMICAL  SPECULATIVE
# 29       CHEMICAL  SPECULATIVE
# 30       CHEMICAL     POSITIVE
# 31       CHEMICAL  SPECULATIVE
# 32       CHEMICAL     POSITIVE
# 33       CHEMICAL     NEGATIVE
# 34  HERB_COMPOUND     POSITIVE
# 35           HERB  SPECULATIVE
# 36       CHEMICAL  SPECULATIVE
# 37       CHEMICAL  SPECULATIVE
# 38       CHEMICAL  SPECULATIVE
# 39       CHEMICAL  SPECULATIVE
# 40       CHEMICAL     POSITIVE

# %%
label_map_dic = {
    "POSITIVE": 0,
    "SPECULATIVE": 1,
    "NEGATIVE": 2,
}

embd_map_dic = {val: i for i, val in label_map_dic.items()}

# %%
embd_map_dic
# Out:
# {0: 'POSITIVE', 1: 'SPECULATIVE', 2: 'NEGATIVE'}

# %%
model_path = './output_biobert/models/bert_model_epoch5/'

# %%
# Instantiate the Bert tokenizer
tokenizer = BertTokenizer.from_pretrained(model_path, do_lower_case=False)
model = BertForSequenceClassification.from_pretrained(model_path,num_labels=len(label_map_dic))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# send model to device
model.to(device);

# %%
def classify_relation(row):
    text = row['sentences'] + str('[SEP]') + row['entity_1_mention'] + str('[SEP]') + row['entity_2_mention']
    input_ids = torch.tensor(tokenizer.encode(text, 
                                              add_special_tokens=True,
                                              max_length=128)).unsqueeze(0)  # Batch size 1
    labels = torch.tensor([1]).unsqueeze(0)  # Batch size 1

    input_ids= input_ids.to(device) 
    labels= labels.to(device)
    with torch.no_grad():
        outputs = model(input_ids, labels=labels)
    logits = outputs[1]
    result = np.argmax(logits.cpu().numpy(),axis=1)[0]
    
    label = embd_map_dic[result]

    return label

# %%
test_df['predicted_type']= test_df.apply(lambda x: classify_relation(x), axis=1)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.

# %%
test_df
# Out:
#     Unnamed: 0                                          sentences  \
# 0            0  the pharmacokinetics of tolbutamide in all vin...
# 1            1  the pharmacokinetics of tolbutamide in all vin...
# 2            2  the plasma concentrations of the six probes we...
# 3            3  the plasma concentrations of the six probes we...
# 4            4  the plasma concentrations of the six probes we...
# 5            5  the plasma concentrations of the six probes we...
# 6            6  the plasma concentrations of the six probes we...
# 7            7  the plasma concentrations of the six probes we...
# 8            8  the reason of different therapeutic effects of...
# 9            9  the reason of different therapeutic effects of...
# 10          10  the reason of different therapeutic effects of...
# 11          11  the reason of different therapeutic effects of...
# 12          12  the st john's wort component, hyperforin, cont...
# 13          13  the st john's wort component, hyperforin, cont...
# 14          14  the t. bellerica/cisplatin or doxorubicin also...
# 15          15  the t. bellerica/cisplatin or doxorubicin also...
# 16          16  the trend of the graphs strongly suggests that...
# 17          17  there was no significant change in clotting ti...
# 18          18  there was no significant change in clotting ti...
# 19          19  there was significant (p < 0.05) potentiation ...
# 20          20  therefore, a. officinarum might have a gastroi...
# 21          21  these interactions were classified depending o...
# 22          22  this case report describes the first known cas...
# 23          23  this case report describes the first known cas...
# 24          24  this in vitro study demonstrated that various ...
# 25          25  this in vitro study demonstrated that various ...
# 26          26  this in vitro study demonstrated that various ...
# 27          27  this paper is a review of possible adverse int...
# 28          28  this study was designed to explore the impact ...
# 29          29  this study was designed to explore the impact ...
# 30          30  tissue distribution results demonstrated that ...
# 31          31  to evaluate whether ape or andrographolide aff...
# 32          32  treatment of radix bupleuri decreased t1/2 and...
# 33          33  treatment of radix bupleuri decreased t1/2 and...
# 34          34  tunel assay was done followed by expression an...
# 35          35  warfarin was the most common drug (18 cases) a...
# 36          36  we set out to study the interactions of g. bil...
# 37          37  we set out to study the interactions of g. bil...
# 38          38  we studied potential interference of ginseng i...
# 39          39  we studied potential interference of ginseng i...
# 40          40  with the discontinuation of the licorice-conta...
#
#                 entity_1_mention entity_1_label              entity_2_mention  \
# 0                    tolbutamide       CHEMICAL  vinegar-baked radix bupleuri
# 1                 radix bupleuri           HERB                   tolbutamide
# 2                      midazolam       CHEMICAL                radix bupleuri
# 3                      midazolam       CHEMICAL  vinegar-baked radix bupleuri
# 4               dextromethorphan       CHEMICAL                radix bupleuri
# 5               dextromethorphan       CHEMICAL  vinegar-baked radix bupleuri
# 6                  chlorzoxazone       CHEMICAL                radix bupleuri
# 7                  chlorzoxazone       CHEMICAL  vinegar-baked radix bupleuri
# 8                 radix bupleuri           HERB                        cyp2c9
# 9   vinegar-baked radix bupleuri           HERB                       cyp2c19
# 10                radix bupleuri           HERB                        cyp2c9
# 11  vinegar-baked radix bupleuri           HERB                       cyp2c19
# 12                st john's wort           HERB                        cyp3a4
# 13                    hyperforin  HERB_COMPOUND                        cyp3a4
# 14                  t. bellerica           HERB                     cisplatin
# 15                  t. bellerica           HERB                   doxorubicin
# 16                st john's wort           HERB                  cyclosporine
# 17                     g. biloba           HERB                    cilostazol
# 18                     g. biloba           HERB                   clopidogrel
# 19                    cilostazol       CHEMICAL                     g. biloba
# 20                a. officinarum           HERB                  indomethacin
# 21                         herbs           HERB                      warfarin
# 22                    paclitaxel       CHEMICAL                      turmeric
# 23                    paclitaxel       CHEMICAL                     chlorella
# 24                          vbrb           HERB             cyp2c9 substrates
# 25                          vbrb           HERB                       cyp1a2-
# 26                          vbrb           HERB      cyp3a4-metabolized drugs
# 27                          khat           HERB            conventional drugs
# 28                      cinnamon           HERB                     metformin
# 29                      cinnamon           HERB                         cyp2d
# 30                a. officinarum           HERB                  indomethacin
# 31               andrographolide  HERB_COMPOUND                   tolbutamide
# 32                radix bupleuri           HERB                    omeprazole
# 33  vinegar-baked radix bupleuri           HERB                    omeprazole
# 34                           dox       CHEMICAL                      curcumin
# 35                      warfarin       CHEMICAL                st john's wort
# 36                     g. biloba           HERB                    cilostazol
# 37                     g. biloba           HERB                   clopidogrel
# 38                       ginseng           HERB                       digoxin
# 39              siberian ginseng           HERB                       digoxin
# 40                      licorice           HERB                spironolactone
#
#    entity_2_label         type predicted_type
# 0            HERB     NEGATIVE       POSITIVE
# 1        CHEMICAL     POSITIVE       POSITIVE
# 2            HERB     POSITIVE    SPECULATIVE
# 3            HERB     POSITIVE    SPECULATIVE
# 4            HERB     POSITIVE    SPECULATIVE
# 5            HERB     POSITIVE    SPECULATIVE
# 6            HERB     POSITIVE    SPECULATIVE
# 7            HERB     POSITIVE    SPECULATIVE
# 8        CHEMICAL     POSITIVE       POSITIVE
# 9        CHEMICAL     POSITIVE       POSITIVE
# 10       CHEMICAL     POSITIVE       POSITIVE
# 11       CHEMICAL     POSITIVE       POSITIVE
# 12       CHEMICAL     POSITIVE       POSITIVE
# 13       CHEMICAL     POSITIVE       POSITIVE
# 14       CHEMICAL     POSITIVE       POSITIVE
# 15       CHEMICAL     POSITIVE       POSITIVE
# 16       CHEMICAL     POSITIVE       POSITIVE
# 17       CHEMICAL     NEGATIVE       NEGATIVE
# 18       CHEMICAL     NEGATIVE       NEGATIVE
# 19           HERB     POSITIVE       POSITIVE
# 20       CHEMICAL     POSITIVE       POSITIVE
# 21       CHEMICAL     POSITIVE    SPECULATIVE
# 22           HERB     POSITIVE       POSITIVE
# 23           HERB     POSITIVE       POSITIVE
# 24       CHEMICAL     POSITIVE       POSITIVE
# 25       CHEMICAL     POSITIVE       POSITIVE
# 26       CHEMICAL     POSITIVE       POSITIVE
# 27       CHEMICAL  SPECULATIVE       POSITIVE
# 28       CHEMICAL  SPECULATIVE    SPECULATIVE
# 29       CHEMICAL  SPECULATIVE    SPECULATIVE
# 30       CHEMICAL     POSITIVE       POSITIVE
# 31       CHEMICAL  SPECULATIVE    SPECULATIVE
# 32       CHEMICAL     POSITIVE       POSITIVE
# 33       CHEMICAL     NEGATIVE       POSITIVE
# 34  HERB_COMPOUND     POSITIVE       POSITIVE
# 35           HERB  SPECULATIVE       POSITIVE
# 36       CHEMICAL  SPECULATIVE    SPECULATIVE
# 37       CHEMICAL  SPECULATIVE    SPECULATIVE
# 38       CHEMICAL  SPECULATIVE    SPECULATIVE
# 39       CHEMICAL  SPECULATIVE    SPECULATIVE
# 40       CHEMICAL     POSITIVE       POSITIVE

# %%
true_vals = {
    label: test_df[(test_df['predicted_type'] == test_df['type']) & (test_df['type'] == label)].shape[0] for label in label_map_dic.keys()
}
true_vals
# Out:
# {'POSITIVE': 21, 'SPECULATIVE': 7, 'NEGATIVE': 2}

# %%
false_vals = {
    label: test_df[(test_df['predicted_type'] != test_df['type']) & (test_df['type'] == label)].shape[0] for label in label_map_dic.keys()
}
false_vals
# Out:
# {'POSITIVE': 7, 'SPECULATIVE': 2, 'NEGATIVE': 2}

# %%
# Calculate the accuracy

accuracy = {
    label: (true_vals[label] / (true_vals[label] + false_vals[label])) * 100 for label in label_map_dic.keys()
}

accuracy
# Out:
# {'POSITIVE': 75.0, 'SPECULATIVE': 77.77777777777779, 'NEGATIVE': 50.0}

# %%
total_accuracy = sum(true_vals.values()) / (sum(true_vals.values()) + sum(false_vals.values())) * 100

# %%
total_accuracy
# Out:
# 73.17073170731707
